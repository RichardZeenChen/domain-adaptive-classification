# %% [markdown]
# # 可视化文件夹中的图像
# # Visualize images in folders

# %% [markdown]
# ## 导入工具包
# ## Import Toolkit

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from mpl_toolkits.axes_grid1 import ImageGrid
# %matplotlib inline

import numpy as np
import math
import os

import cv2

from tqdm import tqdm

from PIL import Image

# %% [markdown]
# ## 指定要将图像可视化的文件夹
# ## Specify the folder where you want to visualize the images

# %%
# folder_path = '../3-【Pytorch】迁移学习训练自己的图像分类模型/z'

# %% [markdown]
# ## 读取文件夹中的所有图像
# ## Read all images in a folder

# %%
# fig = plt.figure(figsize=(10, 10))
# grid = ImageGrid(fig, 111,  # 类似绘制子图 subplot(111)/Similarly plot subplot subplot(111)
#                  nrows_ncols=(3, 6),  # 创建 n 行 m 列的 axes 网格/Creating an axes grid with n rows and m columns
#                  axes_pad=0.01,  # 网格间距/Grid spacing
#                  share_all=True
                
#                  )

# folder_path = '../3-【Pytorch】迁移学习训练自己的图像分类模型/Y'

# N = 42 # Number of pictures
# images = []

# q = list(range(18))

# for each_img in os.listdir(folder_path): # Make images read in order
#     local = each_img[0:2] 
#     l = int(local)-1
#     q[int(l)] = each_img

# for each_img in q: # Process images to a uniform size with CV2 and then convert to rgb
#     img_path = os.path.join(folder_path, each_img)

#     img_bgr = cv2.imread(img_path)
#     resized_image = cv2.resize(img_bgr, (200,200))

#     img_rgb = cv2.cvtColor(resized_image , cv2.COLOR_BGR2RGB)
#     images.append(img_rgb)

    
# # # 遍历每张图像/Iterate over each image
# for ax, im in zip(grid, images):

#     ax.axis('off')
#     ax.imshow(im)
    

# class_lab=['10%  ','30% ','50%      ','80%    ','original   ','100%  '] # Setting labels and adjusting label positions
# domain_lab=['airplane          ','lightning           ','map               ']
# for i,lab in zip(range(6), class_lab): # Read the chart and put it in the appropriate place
# #     print(i)
# #     print(type(lab))
#     xtop_lab = grid[i] 
#     xtop_lab.set_title(lab, fontsize=10) 


# for j,ylab in zip(range(3), domain_lab): #Setting the y label
#     yleft_lab = grid[j*6] 
#     yleft_lab.annotate(ylab,fontsize=10, xy=(0, 0.5),
#                 xytext=(-15,0),rotation=90, ha='right',va='center_baseline'
#                )
    
# # grid[7].annotate('processing'.format(1),fontsize=10,xy=(0, 0.5),
# #                 xytext=(-10,0),rotation=90, ha='right',va='center_baseline'
# #                )
    
# # grid[21].annotate('processing'.format(1),fontsize=10,xy=(0, 0.5),
# #                 xytext=(-10,0),rotation=90, ha='right',va='center_baseline'
# #                )

# # fig.text(0.130,0.15,'real-',ha='center',va='center',fontsize=10)
# # fig.text(0.130,0.13,'scream',ha='center',va='center',fontsize=10)
# # fig.text(0.265,0.15,'real-',ha='center',va='center',fontsize=10)
# # fig.text(0.265,0.13,'wave',ha='center',va='center',fontsize=10)
# # fig.text(0.390,0.15,'real-',ha='center',va='center',fontsize=10)
# # fig.text(0.390,0.13,'udnie',ha='center',va='center',fontsize=10)
# # fig.text(0.525,0.15,'real-denoised',ha='center',va='center',fontsize=10)
# # fig.text(0.525,0.13,'starry',ha='center',va='center',fontsize=10)
# # fig.text(0.655,0.15,'real-',ha='center',va='center',fontsize=10)
# # fig.text(0.655,0.13,'cubist',ha='center',va='center',fontsize=10)
# # fig.text(0.785,0.15,'real-',ha='center',va='center',fontsize=10)
# # fig.text(0.785,0.13,'mosaic',ha='center',va='center',fontsize=10)
# # fig.text(0.915,0.15,'real-',ha='center',va='center',fontsize=10)
# # fig.text(0.915,0.13,'feathers',ha='center',va='center',fontsize=10)



# plt.tight_layout()
# # plt.savefig('./xxx.png')
# plt.savefig('各类别图片数量test26.svg', format='svg', bbox_inches='tight')
# plt.show()

# %% [markdown]
# ## 画图
# ## Drawing pictures

# %%
fig = plt.figure(figsize=(10, 10))
grid = ImageGrid(fig, 111,  # 类似绘制子图 subplot(111)/Similarly plot subplot subplot(111)
                 nrows_ncols=(1, 8),  # 创建 n 行 m 列的 axes 网格/Creating an axes grid with n rows and m columns
                 axes_pad=0.01,  # 网格间距/Grid spacing
                 share_all=True
                
                 )

folder_path = '../3-【Pytorch】迁移学习训练自己的图像分类模型/e'

N = 42
images = []

q = list(range(8))

for each_img in os.listdir(folder_path):
    local = each_img[0:1] 
    l = int(local)-1
    q[int(l)] = each_img

for each_img in q:
    img_path = os.path.join(folder_path, each_img)

    img_bgr = cv2.imread(img_path)
    resized_image = cv2.resize(img_bgr, (200,200))

    img_rgb = cv2.cvtColor(resized_image , cv2.COLOR_BGR2RGB)
    images.append(img_rgb)

    
# # 遍历每张图像/Iterate over each image
for ax, im in zip(grid, images):

    ax.axis('off')
    ax.imshow(im)
    

class_lab=['scream','wave','udnie','denoised-starry','cubist','mosaic','feathers','candy']
# domain_lab=['painting  ','painting- ','real      ','real-    ','sketch   ','real-style  ']
for i,lab in zip(range(8), class_lab):

    xtop_lab = grid[i] 
    xtop_lab.set_title(lab, fontsize=10) 

fig.text(0.925,0.59,'quality-test',ha='center',va='center',fontsize=10)


# for j,ylab in zip(range(6), domain_lab):
#     yleft_lab = grid[j*7] 
#     yleft_lab.annotate(ylab,fontsize=10, xy=(0, 0.5),
#                 xytext=(-35,0),rotation=90, ha='right',va='center_baseline'
#                )
# grid[7].annotate('processing'.format(1),fontsize=10,xy=(0, 0.5),
#                 xytext=(-10,0),rotation=90, ha='right',va='center_baseline'
#                )
    
# grid[21].annotate('processing'.format(1),fontsize=10,xy=(0, 0.5),
#                 xytext=(-10,0),rotation=90, ha='right',va='center_baseline'
#                )


# fig.text(0.130,0.15,'real-',ha='center',va='center',fontsize=10)
# fig.text(0.130,0.13,'scream',ha='center',va='center',fontsize=10)
# fig.text(0.265,0.15,'real-',ha='center',va='center',fontsize=10)
# fig.text(0.265,0.13,'wave',ha='center',va='center',fontsize=10)
# fig.text(0.390,0.15,'real-',ha='center',va='center',fontsize=10)
# fig.text(0.390,0.13,'udnie',ha='center',va='center',fontsize=10)
# fig.text(0.525,0.15,'real-denoised',ha='center',va='center',fontsize=10)
# fig.text(0.525,0.13,'starry',ha='center',va='center',fontsize=10)
# fig.text(0.655,0.15,'real-',ha='center',va='center',fontsize=10)
# fig.text(0.655,0.13,'cubist',ha='center',va='center',fontsize=10)
# fig.text(0.785,0.15,'real-',ha='center',va='center',fontsize=10)
# fig.text(0.785,0.13,'mosaic',ha='center',va='center',fontsize=10)
# fig.text(0.915,0.15,'real-',ha='center',va='center',fontsize=10)
# fig.text(0.915,0.13,'feathers',ha='center',va='center',fontsize=10)


plt.tight_layout()

plt.savefig('各类别图片数量test29.svg', format='svg', bbox_inches='tight')
plt.show()
# Out:
# /home/sha/software/miniconda3/envs/pytorch/lib/python3.7/site-packages/ipykernel_launcher.py:78: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %%
# fig = plt.figure(figsize=(10, 10))
# grid = ImageGrid(fig, 111,  # 类似绘制子图 subplot(111)/Similarly plot subplot subplot(111)
#                  nrows_ncols=(1, 12),  # 创建 n 行 m 列的 axes 网格/Creating an axes grid with n rows and m columns
#                  axes_pad=0.01,  # 网格间距/Grid spacing
#                  share_all=True
                
#                  )

# folder_path = '../3-【Pytorch】迁移学习训练自己的图像分类模型/w'

# N = 42
# images = []

# q = list(range(12))

# for each_img in os.listdir(folder_path):
#     local = each_img[0:2] 
#     l = int(local)-1
#     q[int(l)] = each_img

# for each_img in q:
#     img_path = os.path.join(folder_path, each_img)

#     img_bgr = cv2.imread(img_path)
#     resized_image = cv2.resize(img_bgr, (200,200))

#     img_rgb = cv2.cvtColor(resized_image , cv2.COLOR_BGR2RGB)
#     images.append(img_rgb)

    
# # # 遍历每张图像/Iterate over each image
# for ax, im in zip(grid, images):

#     ax.axis('off')
#     ax.imshow(im)
    

# class_lab=['R   87%','RP  84%','R-S  4%','R-W 73%','P   72%','R-U 71%','PP  70%','R-DS 68%','R-C  66%','R-M  64%','S   63%','R-F  59%']
# # domain_lab=['painting  ','painting- ','real      ','real-    ','sketch   ','real-style  ']
# for i,lab in zip(range(12), class_lab):

#     xtop_lab = grid[i] 
#     xtop_lab.set_title(lab, fontsize=10) 

# # fig.text(0.5,0.60,'denoised',ha='center',va='center',fontsize=10)
# # for j,ylab in zip(range(6), domain_lab):
# #     yleft_lab = grid[j*7] 
# #     yleft_lab.annotate(ylab,fontsize=10, xy=(0, 0.5),
# #                 xytext=(-35,0),rotation=90, ha='right',va='center_baseline'
# #                )
# # grid[7].annotate('processing'.format(1),fontsize=10,xy=(0, 0.5),
# #                 xytext=(-10,0),rotation=90, ha='right',va='center_baseline'
# #                )
    
# # grid[21].annotate('processing'.format(1),fontsize=10,xy=(0, 0.5),
# #                 xytext=(-10,0),rotation=90, ha='right',va='center_baseline'
# #                )


# # fig.text(0.130,0.15,'real-',ha='center',va='center',fontsize=10)
# # fig.text(0.130,0.13,'scream',ha='center',va='center',fontsize=10)
# # fig.text(0.265,0.15,'real-',ha='center',va='center',fontsize=10)
# # fig.text(0.265,0.13,'wave',ha='center',va='center',fontsize=10)
# # fig.text(0.390,0.15,'real-',ha='center',va='center',fontsize=10)
# # fig.text(0.390,0.13,'udnie',ha='center',va='center',fontsize=10)
# # fig.text(0.525,0.15,'real-denoised',ha='center',va='center',fontsize=10)
# # fig.text(0.525,0.13,'starry',ha='center',va='center',fontsize=10)
# # fig.text(0.655,0.15,'real-',ha='center',va='center',fontsize=10)
# # fig.text(0.655,0.13,'cubist',ha='center',va='center',fontsize=10)
# # fig.text(0.785,0.15,'real-',ha='center',va='center',fontsize=10)
# # fig.text(0.785,0.13,'mosaic',ha='center',va='center',fontsize=10)
# # fig.text(0.915,0.15,'real-',ha='center',va='center',fontsize=10)
# # fig.text(0.915,0.13,'feathers',ha='center',va='center',fontsize=10)


# plt.tight_layout()

# plt.savefig('各类别图片数量test25.svg', format='svg', bbox_inches='tight')
# plt.show()
# Out:
# /home/sha/software/miniconda3/envs/pytorch/lib/python3.7/site-packages/ipykernel_launcher.py:76: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %%
# fig = plt.figure(figsize=(6, 7))
# grid = ImageGrid(fig, 111,  # 类似绘制子图 subplot(111)/Similarly plot subplot subplot(111)
#                  nrows_ncols=(6, 7),  # 创建 n 行 m 列的 axes 网格/Creating an axes grid with n rows and m columns
#                  axes_pad=0.01,  # 网格间距/Grid spacing
# #                  label_mode='L',
#                  share_all=True
                
#                  )

# folder_path = '../3-【Pytorch】迁移学习训练自己的图像分类模型/z'

# N = 42
# images = []

# q = list(range(42))

# for each_img in os.listdir(folder_path):
# #     print(each_img)
#     local = each_img[0:2] 
# #     print(local)
#     l = int(local)-1
# #     print(l)
#     q[int(l)] = each_img
# # print(q)
# for each_img in q:
#     img_path = os.path.join(folder_path, each_img)
#     #     image = Image.open(img_path) 
#     img_bgr = cv2.imread(img_path)
#     resized_image = cv2.resize(img_bgr, (200,200))

#     img_rgb = cv2.cvtColor(resized_image , cv2.COLOR_BGR2RGB)
#     images.append(img_rgb)

    
# # # 遍历每张图像/Iterate over each image
# for ax, im in zip(grid, images):

# #     print(images)
#     ax.axis('off')
# #     im = np.resize(im, (10, 10))  # 调整图片大小，根据需要修改/Resize images, modify as needed
# #     im = im.resize(im, (10, 10))
# #     ax.set_title(f"Axes {ax+1}") 
# # Use the np.resize function or refcheck=False    
# #     ax.annotate('Image{}'.format(1),fontsize=10,xy=(0, 0.5),
# #                xytext=(-10,0),rotation=90, fontweight='bold',ha='right',va='center'
# #                )
#     ax.imshow(im)
    

# class_lab=['airplane','bridge','castle','cat','flower','strawberry','tent']
# domain_lab=['painting  ','painting- ','real      ','real-    ','sketch   ','real-style  ']
# for i,lab in zip(range(7), class_lab):
# #     print(i)
# #     print(type(lab))
#     xtop_lab = grid[i] 
#     xtop_lab.set_title(lab, fontsize=10) 


# for j,ylab in zip(range(6), domain_lab):
#     yleft_lab = grid[j*7] 
#     yleft_lab.annotate(ylab,fontsize=10, xy=(0, 0.5),
#                 xytext=(-35,0),rotation=90, ha='right',va='center_baseline'
#                )
# grid[7].annotate('processing'.format(1),fontsize=10,xy=(0, 0.5),
#                 xytext=(-10,0),rotation=90, ha='right',va='center_baseline'
#                )
    
# grid[21].annotate('processing'.format(1),fontsize=10,xy=(0, 0.5),
#                 xytext=(-10,0),rotation=90, ha='right',va='center_baseline'
#                )

# fig.text(0.130,0.15,'real-',ha='center',va='center',fontsize=10)
# fig.text(0.130,0.13,'scream',ha='center',va='center',fontsize=10)
# fig.text(0.265,0.15,'real-',ha='center',va='center',fontsize=10)
# fig.text(0.265,0.13,'wave',ha='center',va='center',fontsize=10)
# fig.text(0.390,0.15,'real-',ha='center',va='center',fontsize=10)
# fig.text(0.390,0.13,'udnie',ha='center',va='center',fontsize=10)
# fig.text(0.525,0.15,'real-denoised',ha='center',va='center',fontsize=10)
# fig.text(0.525,0.13,'starry',ha='center',va='center',fontsize=10)
# fig.text(0.655,0.15,'real-',ha='center',va='center',fontsize=10)
# fig.text(0.655,0.13,'cubist',ha='center',va='center',fontsize=10)
# fig.text(0.785,0.15,'real-',ha='center',va='center',fontsize=10)
# fig.text(0.785,0.13,'mosaic',ha='center',va='center',fontsize=10)
# fig.text(0.915,0.15,'real-',ha='center',va='center',fontsize=10)
# fig.text(0.915,0.13,'feathers',ha='center',va='center',fontsize=10)

# # grid[14].annotate('real'.format(1),fontsize=10,xy=(0, 0.5),
# #                 xytext=(-10,0),rotation=90, ha='right',va='top'
# #                )
# #     xycoords='offset points',fontweight='bold',
# # 'left' is not a valid value for align; supported values are 'top', 'bottom', 'center', 'baseline', 'center_baseline'  
    
    
    
# # grid[0].set_ylabel('Image{}'.format(0+1),fontsize=12)
# # plt.ylabel('xxx')
# # for y,ylab in zip(range(7),domain_lab):
# #     y_lab = grid[y*7]
# #     y_lab.set_ylabel(ylab, fontsize=10)
# # x0_lab = grid[0]  # 第10个元素索引为9/The 10th element is indexed at 9
# # x0_lab.set_title('xxx') 

# plt.tight_layout()
# # plt.savefig('./xxx.png')
# plt.savefig('各类别图片数量test22.svg', format='svg', bbox_inches='tight')
# plt.show()

# %%
# fig = plt.figure(figsize=(10, 10))
# grid = ImageGrid(fig, 111,  # 类似绘制子图 subplot(111)
#                  nrows_ncols=(6, 7),  # 创建 n 行 m 列的 axes 网格
#                  axes_pad=0.01,  # 网格间距
# #                  label_mode='L',
#                  share_all=True
                
#                  )

# folder_path = '../3-【Pytorch】迁移学习训练自己的图像分类模型/z'

# N = 42
# images = []

# q = list(range(42))

# for each_img in os.listdir(folder_path):
# #     print(each_img)
#     local = each_img[0:2] 
# #     print(local)
#     l = int(local)-1
# #     print(l)
#     q[int(l)] = each_img
# # print(q)
# for each_img in q:
#     img_path = os.path.join(folder_path, each_img)
#     #     image = Image.open(img_path) 
#     img_bgr = cv2.imread(img_path)
#     resized_image = cv2.resize(img_bgr, (200,200))

#     img_rgb = cv2.cvtColor(resized_image , cv2.COLOR_BGR2RGB)
#     images.append(img_rgb)

    
# # # 遍历每张图像
# for ax, im in zip(grid, images):

# #     print(images)
#     ax.axis('off')
# #     im = np.resize(im, (10, 10))  # 调整图片大小，根据需要修改
# #     im = im.resize(im, (10, 10))
# #     ax.set_title(f"Axes {ax+1}") 
# # Use the np.resize function or refcheck=False    
# #     ax.annotate('Image{}'.format(1),fontsize=10,xy=(0, 0.5),
# #                xytext=(-10,0),rotation=90, fontweight='bold',ha='right',va='center'
# #                )
#     ax.imshow(im)
    

# class_lab=['airplane','bridge','castle','cat','flower','strawberry','tent']
# domain_lab=['painting          ','painting-       ','real           ','real-           ','sketch           ','real-style         ']
# for i,lab in zip(range(7), class_lab):
# #     print(i)
# #     print(type(lab))
#     xtop_lab = grid[i] 
#     xtop_lab.set_title(lab, fontsize=10) 


# for j,ylab in zip(range(6), domain_lab):
#     yleft_lab = grid[j*7] 
#     yleft_lab.annotate(ylab,fontsize=10, xy=(0, 0.5),
#                 xytext=(-35,0),rotation=90, ha='right',va='center_baseline'
#                )
# grid[7].annotate('processing      '.format(1),fontsize=10,xy=(0, 0.5),
#                 xytext=(-10,0),rotation=90, ha='right',va='center_baseline'
#                )
    
# grid[21].annotate('processing      '.format(1),fontsize=10,xy=(0, 0.5),
#                 xytext=(-10,0),rotation=90, ha='right',va='center_baseline'
#                )

# fig.text(0.118,0.085,'real-',ha='center',va='center',fontsize=10)
# fig.text(0.118,0.07,'scream',ha='center',va='center',fontsize=10)
# fig.text(0.253,0.085,'real-',ha='center',va='center',fontsize=10)
# fig.text(0.253,0.07,'wave',ha='center',va='center',fontsize=10)
# fig.text(0.385,0.085,'real-',ha='center',va='center',fontsize=10)
# fig.text(0.385,0.07,'udnie',ha='center',va='center',fontsize=10)
# fig.text(0.513,0.085,'real-denoised',ha='center',va='center',fontsize=10)
# fig.text(0.513,0.07,'starry',ha='center',va='center',fontsize=10)
# fig.text(0.650,0.085,'real-',ha='center',va='center',fontsize=10)
# fig.text(0.650,0.07,'cubist',ha='center',va='center',fontsize=10)
# fig.text(0.785,0.085,'real-',ha='center',va='center',fontsize=10)
# fig.text(0.785,0.07,'mosaic',ha='center',va='center',fontsize=10)
# fig.text(0.918,0.085,'real-',ha='center',va='center',fontsize=10)
# fig.text(0.918,0.07,'feathers',ha='center',va='center',fontsize=10)

# # grid[14].annotate('real'.format(1),fontsize=10,xy=(0, 0.5),
# #                 xytext=(-10,0),rotation=90, ha='right',va='top'
# #                )
# #     xycoords='offset points',fontweight='bold',
# # 'left' is not a valid value for align; supported values are 'top', 'bottom', 'center', 'baseline', 'center_baseline'  
    
    
    
# # grid[0].set_ylabel('Image{}'.format(0+1),fontsize=12)
# # plt.ylabel('xxx')
# # for y,ylab in zip(range(7),domain_lab):
# #     y_lab = grid[y*7]
# #     y_lab.set_ylabel(ylab, fontsize=10)
# # x0_lab = grid[0]  # 第10个元素索引为9
# # x0_lab.set_title('xxx') 

# plt.tight_layout()
# # plt.savefig('./xxx.png')
# plt.savefig('各类别图片数量test28.svg', format='svg', bbox_inches='tight')
# plt.show()
