# %% [markdown]
# # 图像分类数据集探索统计
# # image classification dataset exploration statistics

# %% [markdown]
# ## 各类别数据个数柱状图和饼状图
# ## Histograms and pie charts of the number of pieces of data by category

# %% [markdown]
# ### 导入工具包
# ### Import toolkit

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ### 设置中文字体（选择对应的操作系统）
# ### Select the corresponding operating system

# %%
# # windows操作系统/ windows
# plt.rcParams['font.sans-serif']=['SimHei']  # 用来正常显示中文标签 
# plt.rcParams['axes.unicode_minus']=False  # 用来正常显示负号

# %%
# Mac操作系统，参考 https://www.ngui.cc/51cto/show-727683.html/Mac
# 下载 simhei.ttf 字体文件
# !wget https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220716-mmclassification/dataset/SimHei.ttf

# %%
# Linux操作系统，例如 云GPU平台：https://featurize.cn/?s=d7ce99f842414bfcaea5662a97581bd1/Linux
# 运行完毕后重启 kernel，再从头运行一次/After running, reboot the kernel and run it again from scratch
# !wget https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220716-mmclassification/dataset/SimHei.ttf -O /environment/miniconda3/lib/python3.7/site-packages/matplotlib/mpl-data/fonts/ttf/SimHei.ttf
# !rm -rf /home/featurize/.cache/matplotlib

import matplotlib

matplotlib.rc("font",family='SimHei') # 中文字体
# plt.rcParams['font.sans-serif']=['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False  # 用来正常显示负号
# Out:
# /environment/miniconda3/lib/python3.7/site-packages/matplotlib/mpl-data/fonts/ttf/SimHei.ttf: 没有那个文件或目录

# %% [markdown]
# ### 导入数据集统计表格
# ### Importing statistical tables for data sets

# %%
df = pd.read_csv('数据量统计.csv')

# %%
df.shape
# Out:
# (114, 4)

# %%
df
# Out:
#                        class  trainset  testset  total
# 0                    snowman     100.0     25.0  125.0
# 1                        sun     100.0     25.0  125.0
# 2                       cake     100.0     25.0  125.0
# 3                  submarine     100.0     25.0  125.0
# 4                   suitcase     100.0     25.0  125.0
# ..                       ...       ...      ...    ...
# 109                    snake     100.0     25.0  125.0
# 110                 elephant     100.0     25.0  125.0
# 111                    tiger     100.0     25.0  125.0
# 112  The-Great-Wall-of-China     100.0     25.0  125.0
# 113                  octopus     100.0     25.0  125.0
#
# [114 rows x 4 columns]

# %% [markdown]
# ### 图像数量柱状图可视化
# ### Visualization of image count histograms

# %%
# 指定可视化的特征/Specify the features to be visualized
feature = 'total'
# feature = 'trainset'
# feature = 'testset'

# %%
df = df.sort_values(by=feature, ascending=False)

# %%
df.head()
# Out:
#        class  trainset  testset  total
# 0    snowman     100.0     25.0  125.0
# 85     camel     100.0     25.0  125.0
# 83      tent     100.0     25.0  125.0
# 82      vase     100.0     25.0  125.0
# 81  slippers     100.0     25.0  125.0

# %%
# # plt.figure(figsize=(22, 7)) /Creating a Canvas


# fig, ax = plt.subplots()

# x = df['class'] # x-coordinate content
# y1 = df[feature] # y-coordinate content
# y2 = df[feature]
# y3 = df[feature]
# y4 = df[feature]
# y5 = df[feature]

# y6 = df[feature]
# # y7 = df[feature]
# # y8 = df[feature]
# # y9 = df[feature]
# # y10 = df[feature]
# # y11 = df[feature]
# # y12 = df[feature]

# params = {
#     'figure.figsize': '22, 4'}
# plt.rcParams.update(params)

# width = 0.65 # column width
# # facecolor='#1f77b4', edgecolor='k'
# plt.bar(x, y1, width, color='mediumorchid', label='real') # Drawing of columns
# plt.bar(x, y2, width, color='goldenrod', label='painting', bottom=y1)
# plt.bar(x, y3, width, color='cadetblue', label='sketch', bottom=y1 + y2)
# plt.bar(x, y4, width, color='olivedrab', label='real-processing', bottom=y1 + y2 + y3)
# plt.bar(x, y5, width, color='coral', label='painting-processing', bottom=y1+y2+y3+y4)
# plt.bar(x, y6, width, color='cyan', label='real-styles', bottom=y1+y2+y3+y4+y5)

# # plt.bar(x, y5, width, color='slategray', label='painting-processing', bottom=y1+y2+y3+y4)
# # plt.bar(x, y6, width, color='coral', label='real-styles', bottom=y1+y2+y3+y4+y5)

# # plt.bar(x, y7, width, color='lightseagreen', label='real-c', bottom=y1+y2+y3+y4+y5+y6)
# # plt.bar(x, y8, width, color='turquoise', label='real-u', bottom=y1+y2+y3+y4+y5+y6+y7)
# # plt.bar(x, y9, width, color='aquamarine', label='real-ds', bottom=y1+y2+y3+y4+y5+y6+y7+y8)
# # plt.bar(x, y10, width, color='mediumaquamarine', label='real-w', bottom=y1+y2+y3+y4+y5+y6+y7+y8)
# # plt.bar(x, y11, width, color='lightgreen', label='real-m', bottom=y1+y2+y3+y4+y5+y6+y7+y8+y9)
# # plt.bar(x, y12, width, color='paleturquoise', label='real-f', bottom=y1+y2+y3+y4+y5+y6+y7+y8+y9+y10)
# # plt.bar(x, y6, width, color='powderblue', label='real-style', bottom=y1+y2+y3+y4+y5+y6+y7+y8+y9+y10+y11)

# ax.set_xlim(-0.35, 113.35)

# plt.legend(fontsize=10) # 图例/legend

# plt.yticks([0, 125, 250, 375, 500, 625, 750, 1000], fontsize=15) # Y-axis labels
# plt.xticks(rotation=90, fontsize=10)
# # plt.tick_params(labelsize=15)
# # plt.xlabel('类别', fontsize=20)
# plt.ylabel('Number of instances', fontsize=20)

# plt.grid(axis='y', c='k', linestyle='--')

# # plt.savefig('各类别图片数量test12.pdf', dpi=300, ) # save
# plt.savefig('各类别图片数量test18.svg', format='svg', bbox_inches='tight')
# # , bbox_inches='tight'
# plt.show()

# %%
# plt.figure(figsize=(22, 7))
# x = df['class']
# y1 = df['testset']
# y2 = df['trainset']

# width = 0.55 # 柱状图宽度/Bar Width

# plt.xticks(rotation=90) # 横轴文字旋转/Horizontal axis text rotation

# plt.bar(x, y1, width, label='text')
# plt.bar(x, y2, width, label='train', bottom=y1)


# # plt.xlabel('class', fontsize=20)
# plt.ylabel('number of images', fontsize=20)
# plt.tick_params(labelsize=13) # 设置坐标文字大小/Set coordinate text size

# plt.legend(fontsize=16) # 图例/legend

# # 保存为高清的 pdf 文件/save
# plt.savefig('R各类别图像数量.pdf', dpi=120, bbox_inches='tight')

# plt.show()

# %%
# # plt.figure(figsize=(22, 7))


# fig, ax = plt.subplots()

# x = df['class']
# y1 = df[feature]
# y2 = df[feature]
# y3 = df[feature]
# y4 = df[feature]
# y5 = df[feature]

# y6 = df[feature]
# # y7 = df[feature]
# # y8 = df[feature]
# # y9 = df[feature]
# # y10 = df[feature]
# # y11 = df[feature]
# # y12 = df[feature]

# params = {
#     'figure.figsize': '22, 4'}
# plt.rcParams.update(params)

# width = 0.65
# # facecolor='#1f77b4', edgecolor='k'
# # plt.bar(x, y1, width, color='mediumorchid', label='real')
# # plt.bar(x, y2, width, color='goldenrod', label='painting', bottom=y1)
# # plt.bar(x, y3, width, color='cadetblue', label='sketch', bottom=y1 + y2)
# # plt.bar(x, y4, width, color='olivedrab', label='real-processing', bottom=y1 + y2 + y3)
# # plt.bar(x, y5, width, color='slategray', label='painting-processing', bottom=y1+y2+y3+y4)
# # plt.bar(x, y6, width, color='coral', label='real-style', bottom=y1+y2+y3+y4+y5)

# plt.bar(x, y1, width, color='lightseagreen', label='real-cubist')
# plt.bar(x, y3, width, color='turquoise', label='real-udnie', bottom=y1)
# plt.bar(x, y4, width, color='aquamarine', label='real-denoised-starry', bottom=y1+y2)
# plt.bar(x, y5, width, color='mediumaquamarine', label='real-wave', bottom=y1+y2+y3)
# plt.bar(x, y6, width, color='lightgreen', label='real-mosaic', bottom=y1+y2+y3+y4)
# plt.bar(x, y2, width, color='paleturquoise', label='real-feathers', bottom=y1+y2+y3+y4+y5)
# plt.bar(x, y7, width, color='powderblue', label='real-scream', bottom=y1+y2+y3+y4+y5+y6)

# ax.set_xlim(-0.35, 113.35)

# plt.legend(fontsize=10) # 图例

# plt.yticks([0, 125, 250, 375, 500, 625, 750, 875, 1000], fontsize=15)
# plt.xticks(rotation=90, fontsize=10)
# # plt.tick_params(labelsize=15)
# # plt.xlabel('类别', fontsize=20)
# plt.ylabel('Number of instances', fontsize=20)

# plt.grid(axis='y', c='k', linestyle='--')

# # plt.savefig('各类别图片数量test12.pdf', dpi=300, )
# plt.savefig('各类别图片数量test16.svg', format='svg', bbox_inches='tight')
# # , bbox_inches='tight'
# plt.show()

# %%
# # plt.figure(figsize=(22, 7)) # Setting the canvas size


# fig, ax = plt.subplots()

params = {
    'figure.figsize': '4, 4'}
plt.rcParams.update(params)



custom_labels1 = [250,250,250] # Assigning content size

# x = df['class']
# y1 = df[feature]


sizes = [2, 2, 2]
labels = ['REAL','PAINTING','SKETCH']
colors = ['darkcyan', 'olivedrab', 'goldenrod']

# plt.axes([0.025, 0.025, 0.85, 0.85])
plt.pie(sizes, labels=labels, colors=colors,textprops={'size': 'larger'},) # pie chart

# textprops={'size': 'larger'},center=(1,1),frame=True

# # 设置内标签
# plt.gca().set_aspect('equal')
# plt.title('gg')

# 添加自定义标签/Adding custom labels
plt.text(-0.6,0,str(custom_labels1[0]), fontsize=12, color='w')
plt.text(0.1,0.4,str(custom_labels1[0]), fontsize=12, color='w')
plt.text(0.1,-0.4,str(custom_labels1[0]), fontsize=12, color='w')

# autopct=['125', '125', '125','125', '125', '125']
# x2 = [1, 1, 1, 1, 1, 1]
# labels = ['real1','real2','painting1','painting2','sketch1','sketch2']
# colors = ['darkcyan','c', 'olivedrab','yellowgreen', 'gold','goldenrod']

# plt.pie(x2, labels=labels, colors = colors)






# # plt.savefig('各类别图片数量test12.pdf', dpi=300, )
plt.savefig('各类别图片数量test19.svg', format='svg', bbox_inches='tight') # save
# # , bbox_inches='tight'
plt.show()

# %%
# fig1, ax1 = plt.subplots()

params = {
    'figure.figsize': '4, 4'}
plt.rcParams.update(params)

# custom_labels = [250,250,250]
# custom_labels2 = ['125', '125', '125','125', '125', '125']
# custom_labels3 = ['REAL','PAINTING','SKETCH']
custom_labels5 = ['real2', 'sketch1']

# sizes = [2, 2, 2]
# labels = ['REAL','PAINTING','SKETCH']
# colors = ['teal', 'darkolivegreen', 'darkgoldenrod']

# autopct=['125', '125', '125','125', '125', '125']
sizes = [1, 1, 1, 1, 1, 1]

labels = ['real1','','painting1','painting2','','sketch2']
# labels=labels,

colors = ['darkcyan','c', 'olivedrab','yellowgreen', 'gold','goldenrod']

# plt.pie(sizes,  colors=colors,textprops={'size': 'larger'}, center=(0,0),frame=True)

plt.pie(sizes,labels=labels,colors=colors,textprops={'size': 'larger'}, center=(0,0),frame=False)
# ax1.axis('equal') 
# plt.pie(sizes,colors=colors,textprops={'size': 'larger'}, center=(0,0),frame=False)

# Setting up custom labels
plt.text(0,0.6,str(custom_labels2[0]), fontsize=12, color='w', ha='center', va='center')
plt.text(0,-0.6,str(custom_labels2[0]), fontsize=12, color='w', ha='center', va='center')
plt.text(0.52,-0.3,str(custom_labels2[0]), fontsize=12, color='w', ha='center', va='center')
plt.text(0.52,0.3,str(custom_labels2[0]), fontsize=12, color='w', ha='center', va='center')
plt.text(-0.52,-0.3,str(custom_labels2[0]), fontsize=12, color='w', ha='center', va='center')
plt.text(-0.52,0.3,str(custom_labels2[0]), fontsize=12, color='w', ha='center', va='center')

plt.text(0,1.15,str(custom_labels5[0]), fontsize=12, color='k', ha='center', va='center')
plt.text(0,-1.15,str(custom_labels5[1]), fontsize=12, color='k', ha='center', va='center')
# plt.text(1.1,-1.1,str(custom_labels3[2]), fontsize=15, color='k', ha='center', va='center')
# plt.text(0.52,0.3,str(custom_labels2[0]), fontsize=12, color='w', ha='center', va='center')
# plt.text(-0.52,-0.3,str(custom_labels2[0]), fontsize=12, color='w', ha='center', va='center')
# plt.text(-0.52,0.3,str(custom_labels2[0]), fontsize=12, color='w', ha='center', va='center')

plt.savefig('各类别图片数量test20.svg', format='svg', bbox_inches='tight')


plt.show()

# %%
# fig1, ax1 = plt.subplots()

params = {
    'figure.figsize': '4, 4'}
plt.rcParams.update(params)

# custom_labels = [250,250,250]
# custom_labels2 = ['125', '125', '125','125', '125', '125']
# custom_labels3 = ['REAL','PAINTING','SKETCH']
custom_labels4 = ['real-processing+real-styles', 'sketch1(SAVE)']


# sizes = [2, 2, 2]
# labels = ['REAL','PAINTING','SKETCH']
# colors = ['teal', 'darkolivegreen', 'darkgoldenrod']

# autopct=['125', '125', '125','125', '125', '125']
sizes = [1, 1, 1, 1, 1, 1]

labels = ['real','','painting','painting-processing','','sketch']
# labels=labels,

colors = ['darkcyan','c', 'olivedrab','yellowgreen', 'gold','goldenrod']

# plt.pie(sizes,  colors=colors,textprops={'size': 'larger'}, center=(0,0),frame=True)

plt.pie(sizes,labels=labels,colors=colors,textprops={'size': 'larger'}, center=(0,0),frame=False)
# ax1.axis('equal') 
# plt.pie(sizes,colors=colors,textprops={'size': 'larger'}, center=(0,0),frame=False)

plt.text(0,0.6,str(custom_labels2[0]), fontsize=12, color='w', ha='center', va='center')
plt.text(0,-0.6,str(custom_labels2[0]), fontsize=12, color='w', ha='center', va='center')
plt.text(0.52,-0.3,str(custom_labels2[0]), fontsize=12, color='w', ha='center', va='center')
plt.text(0.52,0.3,str(custom_labels2[0]), fontsize=12, color='w', ha='center', va='center')
plt.text(-0.52,-0.3,str(custom_labels2[0]), fontsize=12, color='w', ha='center', va='center')
plt.text(-0.52,0.3,str(custom_labels2[0]), fontsize=12, color='w', ha='center', va='center')

plt.text(0,1.15,str(custom_labels4[0]), fontsize=12, color='k', ha='center', va='center')
plt.text(0,-1.15,str(custom_labels4[1]), fontsize=12, color='k', ha='center', va='center')
# plt.text(1.1,-1.1,str(custom_labels3[2]), fontsize=15, color='k', ha='center', va='center')
# plt.text(0.52,0.3,str(custom_labels2[0]), fontsize=12, color='w', ha='center', va='center')
# plt.text(-0.52,-0.3,str(custom_labels2[0]), fontsize=12, color='w', ha='center', va='center')
# plt.text(-0.52,0.3,str(custom_labels2[0]), fontsize=12, color='w', ha='center', va='center')

plt.savefig('各类别图片数量test21.svg', format='svg', bbox_inches='tight')


plt.show()
